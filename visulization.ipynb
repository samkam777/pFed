# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
 def process_privacy_data(filename):
    file = open(filename)
    dataMat = []
    for line in file.readlines():
        dataMat.append(float(line))
    return dataMat

# %% [markdown]
# ### python 颜色表https://blog.csdn.net/qq_42612717/article/details/106291819

# %% [markdown]
# # lamda调整

# %%
unbalance_lamda_0_0000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-07_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-06_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_00001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-05_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_0001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_01_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.01_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.1_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1.0_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_0000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-07_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-06_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_00001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-05_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_0001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_01_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.01_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.1_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1.0_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")


epochs = [x for x in range(0, 60, 1)]

plt.plot(epochs, unbalance_lamda_0_0000001_HR, '--', label='unbalance lamda 0.0000001')
plt.plot(epochs, unbalance_lamda_0_000001_HR, '--', label='unbalance lamda 0.000001')
plt.plot(epochs, unbalance_lamda_0_00001_HR, '--', label='unbalance lamda 0.00001')
plt.plot(epochs, unbalance_lamda_0_0001_HR, '--', label='unbalance lamda 0.0001')
plt.plot(epochs, unbalance_lamda_0_001_HR, '--', label='unbalance lamda 0.001')
plt.plot(epochs, unbalance_lamda_0_01_HR, '--', label='unbalance lamda 0.01')
plt.plot(epochs, unbalance_lamda_0_1_HR, '--', label='unbalance lamda 0.1')
plt.plot(epochs, unbalance_lamda_1_HR, '--', label='unbalance lamda 1.0')
plt.plot(epochs, balance_lamda_0_0000001_HR, '-', label='balance lamda 0.0000001')
plt.plot(epochs, balance_lamda_0_000001_HR, '-', label='balance lamda 0.000001')
plt.plot(epochs, balance_lamda_0_00001_HR, '-', label='balance lamda 0.00001')
plt.plot(epochs, balance_lamda_0_0001_HR, '-', label='balance lamda 0.0001')
plt.plot(epochs, balance_lamda_0_001_HR, '-', label='balance lamda 0.001')
plt.plot(epochs, balance_lamda_0_01_HR, '-', label='balance lamda 0.01')
plt.plot(epochs, balance_lamda_0_1_HR, '-', label='balance lamda 0.1')
plt.plot(epochs, balance_lamda_1_HR, '-', label='balance lamda 1.0')

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
# plt.title('FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 23)
plt.savefig(r"./result/pFed_lamda/lamda_balance_unbalance_HR")

# %% [markdown]
# ## 平衡数据

# %%
unbalance_lamda_0_0000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-07_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-06_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_00001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-05_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_0001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_01_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.01_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.1_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1.0_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_0000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-07_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-06_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_00001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-05_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_0001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_01_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.01_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.1_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1.0_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")


epochs = [x for x in range(0, 60, 1)]

#plt.plot(epochs, unbalance_lamda_0_0000001_HR, '--', label='unbalance lamda 0.0000001')
#plt.plot(epochs, unbalance_lamda_0_000001_HR, '--', label='unbalance lamda 0.000001')
#plt.plot(epochs, unbalance_lamda_0_00001_HR, '--', label='unbalance lamda 0.00001')
#plt.plot(epochs, unbalance_lamda_0_0001_HR, '--', label='unbalance lamda 0.0001')
#plt.plot(epochs, unbalance_lamda_0_001_HR, '--', label='unbalance lamda 0.001')
#plt.plot(epochs, unbalance_lamda_0_01_HR, '--', label='unbalance lamda 0.01')
#plt.plot(epochs, unbalance_lamda_0_1_HR, '--', label='unbalance lamda 0.1')
#plt.plot(epochs, unbalance_lamda_1_HR, '--', label='unbalance lamda 1.0')
plt.plot(epochs, balance_lamda_0_0000001_HR, '-', label='balance lamda 0.0000001')
plt.plot(epochs, balance_lamda_0_000001_HR, '-', label='balance lamda 0.000001')
plt.plot(epochs, balance_lamda_0_00001_HR, '-', label='balance lamda 0.00001')
plt.plot(epochs, balance_lamda_0_0001_HR, '-', label='balance lamda 0.0001')
plt.plot(epochs, balance_lamda_0_001_HR, '-', label='balance lamda 0.001')
plt.plot(epochs, balance_lamda_0_01_HR, '-', label='balance lamda 0.01')
plt.plot(epochs, balance_lamda_0_1_HR, '-', label='balance lamda 0.1')
plt.plot(epochs, balance_lamda_1_HR, '-', label='balance lamda 1.0')

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
# plt.title('FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 16)
plt.savefig(r"./result/pFed_lamda/lamda_balance_HR")

# %% [markdown]
# ## 不平衡数据

# %%
unbalance_lamda_0_0000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-07_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-06_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_00001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-05_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_0001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_01_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.01_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_0_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.1_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lamda_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1.0_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_0000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-07_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_000001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-06_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_00001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1e-05_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_0001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_001_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_01_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.01_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_0_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.1_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lamda_1_HR = process_privacy_data(r"./2021-09-21-16-28-43/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_1.0_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")


epochs = [x for x in range(0, 60, 1)]

plt.plot(epochs, unbalance_lamda_0_0000001_HR, '--', label='unbalance lamda 0.0000001')
plt.plot(epochs, unbalance_lamda_0_000001_HR, '--', label='unbalance lamda 0.000001')
plt.plot(epochs, unbalance_lamda_0_00001_HR, '--', label='unbalance lamda 0.00001')
plt.plot(epochs, unbalance_lamda_0_0001_HR, '--', label='unbalance lamda 0.0001')
plt.plot(epochs, unbalance_lamda_0_001_HR, '--', label='unbalance lamda 0.001')
plt.plot(epochs, unbalance_lamda_0_01_HR, '--', label='unbalance lamda 0.01')
plt.plot(epochs, unbalance_lamda_0_1_HR, '--', label='unbalance lamda 0.1')
plt.plot(epochs, unbalance_lamda_1_HR, '--', label='unbalance lamda 1.0')
#plt.plot(epochs, balance_lamda_0_0000001_HR, '-', label='balance lamda 0.0000001')
#plt.plot(epochs, balance_lamda_0_000001_HR, '-', label='balance lamda 0.000001')
#plt.plot(epochs, balance_lamda_0_00001_HR, '-', label='balance lamda 0.00001')
#plt.plot(epochs, balance_lamda_0_0001_HR, '-', label='balance lamda 0.0001')
#plt.plot(epochs, balance_lamda_0_001_HR, '-', label='balance lamda 0.001')
#plt.plot(epochs, balance_lamda_0_01_HR, '-', label='balance lamda 0.01')
#plt.plot(epochs, balance_lamda_0_1_HR, '-', label='balance lamda 0.1')
#plt.plot(epochs, balance_lamda_1_HR, '-', label='balance lamda 1.0')

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
# plt.title('FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 16)
plt.savefig(r"./result/pFed_lamda/lamda_unbalance_HR")

# %% [markdown]
# ## global lr调整

# %%
unbalance_lr_0_0001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.0001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_0001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.0001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_01_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_01_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_02_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.02_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_02_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.02_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_04_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.04_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_04_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.04_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_06_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.06_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_06_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.06_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_08_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.08_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_08_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.08_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.1_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.1_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_1.0_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_1.0_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")


epochs = [x for x in range(0, 60, 1)]

plt.plot(epochs, unbalance_lr_0_0001_HR, '--', label='unbalance lr 0.0001')
plt.plot(epochs, unbalance_lr_0_001_HR, '--', label='unbalance lr 0.001')
plt.plot(epochs, unbalance_lr_0_01_HR, '--', label='unbalance lr 0.01')
plt.plot(epochs, unbalance_lr_0_02_HR, '--', label='unbalance lr 0.02')
plt.plot(epochs, unbalance_lr_0_04_HR, '--', label='unbalance lr 0.04')
plt.plot(epochs, unbalance_lr_0_06_HR, '--', label='unbalance lr 0.06')
plt.plot(epochs, unbalance_lr_0_08_HR, '--', label='unbalance lr 0.08')
plt.plot(epochs, unbalance_lr_0_1_HR, '--', label='unbalance lr 0.1')
plt.plot(epochs, unbalance_lr_1_HR, '--', label='unbalance lr 1.0')

plt.plot(epochs, balance_lr_0_0001_HR, '-', label='unbalance lr 0.0001')
plt.plot(epochs, balance_lr_0_001_HR, '-', label='unbalance lr 0.001')
plt.plot(epochs, balance_lr_0_01_HR, '-', label='unbalance lr 0.01')
plt.plot(epochs, balance_lr_0_02_HR, '-', label='unbalance lr 0.02')
plt.plot(epochs, balance_lr_0_04_HR, '-', label='unbalance lr 0.04')
plt.plot(epochs, balance_lr_0_06_HR, '-', label='unbalance lr 0.06')
plt.plot(epochs, balance_lr_0_08_HR, '-', label='unbalance lr 0.08')
plt.plot(epochs, balance_lr_0_1_HR, '-', label='unbalance lr 0.1')
plt.plot(epochs, balance_lr_1_HR, '-', label='unbalance lr 1.0')

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
# plt.title('FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 22)
plt.savefig(r"./result/pFed_lr/lr_balance_unbalance_HR")

# %%
unbalance_lr_0_0001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.0001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_0001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.0001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_01_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_01_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_02_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.02_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_02_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.02_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_04_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.04_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_04_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.04_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_06_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.06_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_06_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.06_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_08_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.08_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_08_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.08_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.1_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.1_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_1.0_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_1.0_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")


epochs = [x for x in range(0, 60, 1)]

# plt.plot(epochs, unbalance_lr_0_0001_HR, '--', label='unbalance lr 0.0001')
# plt.plot(epochs, unbalance_lr_0_001_HR, '--', label='unbalance lr 0.001')
# plt.plot(epochs, unbalance_lr_0_01_HR, '--', label='unbalance lr 0.01')
# plt.plot(epochs, unbalance_lr_0_1_HR, '--', label='unbalance lr 0.1')
# plt.plot(epochs, unbalance_lr_1_HR, '--', label='unbalance lr 1.0')

plt.plot(epochs, balance_lr_0_0001_HR, '-', label='unbalance lr 0.0001')
plt.plot(epochs, balance_lr_0_001_HR, '-', label='unbalance lr 0.001')
plt.plot(epochs, balance_lr_0_01_HR, '-', label='unbalance lr 0.01')
plt.plot(epochs, balance_lr_0_02_HR, '-', label='unbalance lr 0.02')
plt.plot(epochs, balance_lr_0_04_HR, '-', label='unbalance lr 0.04')
plt.plot(epochs, balance_lr_0_06_HR, '-', label='unbalance lr 0.06')
plt.plot(epochs, balance_lr_0_08_HR, '-', label='unbalance lr 0.08')
plt.plot(epochs, balance_lr_0_1_HR, '-', label='unbalance lr 0.1')
plt.plot(epochs, balance_lr_1_HR, '-', label='unbalance lr 1.0')

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
# plt.title('FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 16)
plt.savefig(r"./result/pFed_lr/lr_balance_HR")

# %%
unbalance_lr_0_0001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.0001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_0001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.0001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_001_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.001_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_01_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_01_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.01_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_02_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.02_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_02_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.02_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_04_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.04_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_04_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.04_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_06_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.06_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_06_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.06_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_08_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.08_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_08_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.08_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_0_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.1_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_0_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.1_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
unbalance_lr_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_1.0_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")
balance_lr_1_HR = process_privacy_data(r"./2021-09-23-09-55-15/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_1.0_PersonalLr_0.01_lamda_0.0001_loss_reduction_mean_/logs/server/total_test_HR/total_test_HR.txt")


epochs = [x for x in range(0, 60, 1)]

plt.plot(epochs, unbalance_lr_0_0001_HR, '--', label='unbalance lr 0.0001')
plt.plot(epochs, unbalance_lr_0_001_HR, '--', label='unbalance lr 0.001')
plt.plot(epochs, unbalance_lr_0_01_HR, '--', label='unbalance lr 0.01')
plt.plot(epochs, unbalance_lr_0_02_HR, '--', label='unbalance lr 0.02')
plt.plot(epochs, unbalance_lr_0_04_HR, '--', label='unbalance lr 0.04')
plt.plot(epochs, unbalance_lr_0_06_HR, '--', label='unbalance lr 0.06')
plt.plot(epochs, unbalance_lr_0_08_HR, '--', label='unbalance lr 0.08')
plt.plot(epochs, unbalance_lr_0_1_HR, '--', label='unbalance lr 0.1')
plt.plot(epochs, unbalance_lr_1_HR, '--', label='unbalance lr 1.0')

# plt.plot(epochs, balance_lr_0_0001_HR, '-', label='unbalance lr 0.0001')
# plt.plot(epochs, balance_lr_0_001_HR, '-', label='unbalance lr 0.001')
# plt.plot(epochs, balance_lr_0_01_HR, '-', label='unbalance lr 0.01')
# plt.plot(epochs, balance_lr_0_02_HR, '-', label='unbalance lr 0.02')
# plt.plot(epochs, balance_lr_0_04_HR, '-', label='unbalance lr 0.04')
# plt.plot(epochs, balance_lr_0_06_HR, '-', label='unbalance lr 0.06')
# plt.plot(epochs, balance_lr_0_08_HR, '-', label='unbalance lr 0.08')
# plt.plot(epochs, balance_lr_0_1_HR, '-', label='unbalance lr 0.1')
# plt.plot(epochs, balance_lr_1_HR, '-', label='unbalance lr 1.0')

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)

# plt.title('FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 16)
plt.savefig(r"./result/pFed_lr/lr_unbalance_HR")
