# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
 def process_privacy_data(filename):
    file = open(filename)
    dataMat = []
    for line in file.readlines():
        dataMat.append(float(line))
    return dataMat

# %% [markdown]
# ### python 颜色表https://blog.csdn.net/qq_42612717/article/details/106291819

# %% [markdown]
# # 不平衡数据 同一算法 不同用户数量

# %% [markdown]
# ## HR FedAvg

# %%
user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user20_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_20_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user50_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_50_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, user5_HR, label='user 5')
plt.plot(epochs, user10_HR, label='user 10')
plt.plot(epochs, user20_HR, label='user 20')
plt.plot(epochs, user50_HR, label='user 50')


plt.legend()
plt.xlabel('epochs')
plt.ylabel('HR')
plt.title('FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12, 10)
plt.savefig(r"./result/FedAvg/unbalance_HR")

# %% [markdown]
# ## NDCG FedAvg

# %%
user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user20_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_20_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user50_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_50_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, user5_NDCG, label='user 5')
plt.plot(epochs, user10_NDCG, label='user 10')
plt.plot(epochs, user20_NDCG, label='user 20')
plt.plot(epochs, user50_NDCG, label='user 50')


plt.legend()
plt.xlabel('epochs')
plt.ylabel('NDCG')
plt.title('FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12, 10)
plt.savefig(r"./result/FedAvg/unbalance_NDCG")

# %% [markdown]
# ## HR pFed

# %%
# HR user数量差别 pFed
user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user20_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_20_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user50_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_50_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, user5_HR, label='user 5')
plt.plot(epochs, user10_HR, label='user 10')
plt.plot(epochs, user20_HR, label='user 20')
plt.plot(epochs, user50_HR, label='user 50')

plt.legend()
plt.xlabel('epochs')
plt.ylabel('HR')
plt.title('pFed unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12, 10)
plt.savefig(r"./result/pFed/unbalance_HR")

# %% [markdown]
# ## NDCG pFed

# %%
user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user20_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_20_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user50_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_50_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, user5_NDCG, label='user 5')
plt.plot(epochs, user10_NDCG, label='user 10')
plt.plot(epochs, user20_NDCG, label='user 20')
plt.plot(epochs, user50_NDCG, label='user 50')

plt.legend()
plt.xlabel('epochs')
plt.ylabel('NDCG')
plt.title('pFed unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12, 10)
plt.savefig(r"./result/pFed/unbalance_NDCG")

# %% [markdown]
# # 平衡数据 同一算法 不同用户数量

# %% [markdown]
# ## HR FedAvg

# %%
user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user20_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_20_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user50_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_50_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, user5_HR, label='user 5')
plt.plot(epochs, user10_HR, label='user 10')
plt.plot(epochs, user20_HR, label='user 20')
plt.plot(epochs, user50_HR, label='user 50')

plt.legend()
plt.xlabel('epochs')
plt.ylabel('HR')
plt.title('FedAvg balance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12, 10)
plt.savefig(r"./result/FedAvg/balance_HR")

# %% [markdown]
# ## NDCG FedAvg

# %%
user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user20_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_20_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user50_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_50_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, user5_NDCG, label='user 5')
plt.plot(epochs, user10_NDCG, label='user 10')
plt.plot(epochs, user20_NDCG, label='user 20')
plt.plot(epochs, user50_NDCG, label='user 50')


plt.legend()
plt.xlabel('epochs')
plt.ylabel('NDCG')
plt.title('FedAvg balance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12, 10)
plt.savefig(r"./result/FedAvg/balance_NDCG")

# %% [markdown]
# ## HR pFed

# %%
user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user20_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_20_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
user50_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_50_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, user5_HR, label='user 5')
plt.plot(epochs, user10_HR, label='user 10')
plt.plot(epochs, user20_HR, label='user 20')
plt.plot(epochs, user50_HR, label='user 50')


plt.legend()
plt.xlabel('epochs')
plt.ylabel('HR')
plt.title('pFed balance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12, 10)
plt.savefig(r"./result/pFed/balance_HR")

# %% [markdown]
# ## NDCG pFed

# %%
user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user20_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_20_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
user50_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_50_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, user5_NDCG, label='user 5')
plt.plot(epochs, user10_NDCG, label='user 10')
plt.plot(epochs, user20_NDCG, label='user 20')
plt.plot(epochs, user50_NDCG, label='user 50')

plt.legend()
plt.xlabel('epochs')
plt.ylabel('NDCG')
plt.title('pFed balance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12, 10)
plt.savefig(r"./result/pFed/balance_NDCG")

# %% [markdown]
# # 平衡数据 不同算法 不同用户数量

# %% [markdown]
# ## HR FedAvg pFed

# %%
FedAvg_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_user20_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_20_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_user50_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_50_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

pFedMe_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_user20_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_20_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_user50_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_50_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, FedAvg_user5_HR, 'b'+'--', label='FedAvg user 5',linewidth=2)
plt.plot(epochs, FedAvg_user10_HR, 'm'+'--', label='FedAvg user 10',linewidth=2)
plt.plot(epochs, FedAvg_user20_HR, 'g'+'--', label='FedAvg user 20',linewidth=2)
plt.plot(epochs, FedAvg_user50_HR, 'y'+'--', label='FedAvg user 50',linewidth=2)
plt.plot(epochs, pFedMe_user5_HR, 'b'+'-', label='pFed user 5',linewidth=2)
plt.plot(epochs, pFedMe_user10_HR, 'm'+'-', label='pFed user 10',linewidth=2)
plt.plot(epochs, pFedMe_user20_HR, 'g'+'-', label='pFed user 20',linewidth=2)
plt.plot(epochs, pFedMe_user50_HR, 'y'+'-', label='pFed user 50',linewidth=2)

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
#plt.title('pFed FedAvg balance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 16)
plt.savefig(r"./result/compare/balance_HR")

# %% [markdown]
# ## NDCG FedAvg pFed

# %%
FedAvg_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_user20_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_20_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_user50_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_50_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

pFedMe_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_user20_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_20_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_user50_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_50_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, FedAvg_user5_NDCG, 'b'+'--', label='FedAvg user 5',linewidth=2)
plt.plot(epochs, FedAvg_user10_NDCG, 'm'+'--', label='FedAvg user 10',linewidth=2)
plt.plot(epochs, FedAvg_user20_NDCG, 'g'+'--', label='FedAvg user 20',linewidth=2)
plt.plot(epochs, FedAvg_user50_NDCG, 'y'+'--', label='FedAvg user 50',linewidth=2)
plt.plot(epochs, pFedMe_user5_NDCG, 'b'+'-', label='pFed user 5',linewidth=2)
plt.plot(epochs, pFedMe_user10_NDCG, 'm'+'-', label='pFed user 10',linewidth=2)
plt.plot(epochs, pFedMe_user20_NDCG, 'g'+'-', label='pFed user 20',linewidth=2)
plt.plot(epochs, pFedMe_user50_NDCG, 'y'+'-', label='pFed user 50',linewidth=2)

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('NDCG', font1)
#plt.title('pFed FedAvg balance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 16)
plt.savefig(r"./result/compare/balance_NDCG")

# %% [markdown]
# # 不平衡数据 不同算法 不同用户数量

# %% [markdown]
# ## HR FedAvg pFed

# %%
FedAvg_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_user20_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_20_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_user50_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_50_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

pFedMe_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_user20_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_20_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_user50_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_50_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, FedAvg_user5_HR, 'b'+'--', label='FedAvg user 5',linewidth=2)
plt.plot(epochs, FedAvg_user10_HR, 'm'+'--', label='FedAvg user 10',linewidth=2)
plt.plot(epochs, FedAvg_user20_HR, 'g'+'--', label='FedAvg user 20',linewidth=2)
plt.plot(epochs, FedAvg_user50_HR, 'y'+'--', label='FedAvg user 50',linewidth=2)
plt.plot(epochs, pFedMe_user5_HR, 'b'+'-', label='pFed user 5',linewidth=2)
plt.plot(epochs, pFedMe_user10_HR, 'm'+'-', label='pFed user 10',linewidth=2)
plt.plot(epochs, pFedMe_user20_HR, 'g'+'-', label='pFed user 20',linewidth=2)
plt.plot(epochs, pFedMe_user50_HR, 'y'+'-', label='pFed user 50',linewidth=2)

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
#plt.title('pFed FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 16)
plt.savefig(r"./result/compare/unbalance_HR")

# %% [markdown]
# ## NDCG FedAvg pFed

# %%
FedAvg_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_user20_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_20_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_user50_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_50_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

pFedMe_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_user20_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_20_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_user50_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_50_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, FedAvg_user5_NDCG, 'b'+'--', label='FedAvg user 5',linewidth=2)
plt.plot(epochs, FedAvg_user10_NDCG, 'm'+'--', label='FedAvg user 10',linewidth=2)
plt.plot(epochs, FedAvg_user20_NDCG, 'g'+'--', label='FedAvg user 20',linewidth=2)
plt.plot(epochs, FedAvg_user50_NDCG, 'y'+'--', label='FedAvg user 50',linewidth=2)
plt.plot(epochs, pFedMe_user5_NDCG, 'b'+'-', label='pFed user 5',linewidth=2)
plt.plot(epochs, pFedMe_user10_NDCG, 'm'+'-', label='pFed user 10',linewidth=2)
plt.plot(epochs, pFedMe_user20_NDCG, 'g'+'-', label='pFed user 20',linewidth=2)
plt.plot(epochs, pFedMe_user50_NDCG, 'y'+'-', label='pFed user 50',linewidth=2)

font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('NDCG', font1)
#plt.title('pFed FedAvg unbalance data')

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 16)
plt.savefig(r"./result/compare/unbalance_NDCG")

# %% [markdown]
# #

# %% [markdown]
# # 平衡数据与不平衡数据的实验差距

# %%
pFedMe_balance_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_unbalance_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_balance_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_unbalance_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_balance_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_unbalance_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_balance_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_unbalance_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

#plt.axis([0, 40, 0, 0.7])
epochs = [x for x in range(0, 80, 1)]

#plt.plot(epochs, pFedMe_balance_user5_HR, 'b'+'--', label='pFed user 5 balance data',linewidth=2)
#plt.plot(epochs, pFedMe_unbalance_user5_HR, 'm'+'--', label='pFed user 5 unbalance data',linewidth=2)
plt.plot(epochs, pFedMe_balance_user10_HR, 'b'+'-', label='pFed user 10 balance data',linewidth=2)
plt.plot(epochs, pFedMe_unbalance_user10_HR, 'b'+'--', label='pFed user 10 unbalance data',linewidth=2)
#plt.plot(epochs, FedAvg_balance_user5_HR, 'g'+'--', label='FedAvg user 5 balance data',linewidth=2)
#plt.plot(epochs, FedAvg_unbalance_user5_HR, 'y'+'--', label='FedAvg user 5 unbalance data',linewidth=2)
plt.plot(epochs, FedAvg_balance_user10_HR, 'g'+'-', label='FedAvg user 10 balance data',linewidth=2)
plt.plot(epochs, FedAvg_unbalance_user10_HR, 'g'+'--', label='FedAvg user 10 unbalance data',linewidth=2)


font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
plt.title('balance & unbalance', font1)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 14)
plt.savefig(r"./result/compare/user_10_balance_and_unbalance_HR")

# %%
pFedMe_balance_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_unbalance_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_balance_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_unbalance_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_balance_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_unbalance_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_balance_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_unbalance_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

#plt.axis([0, 40, 0, 0.5])
epochs = [x for x in range(0, 80, 1)]

#plt.plot(epochs, pFedMe_balance_user5_NDCG, 'b'+'--', label='pFed user 5 balance data',linewidth=2)
#plt.plot(epochs, pFedMe_unbalance_user5_NDCG, 'm'+'--', label='pFed user 5 unbalance data',linewidth=2)
plt.plot(epochs, pFedMe_balance_user10_NDCG, 'b'+'-', label='pFed user 10 balance data',linewidth=2)
plt.plot(epochs, pFedMe_unbalance_user10_NDCG, 'b'+'--', label='pFed user 10 unbalance data',linewidth=2)
#plt.plot(epochs, FedAvg_balance_user5_NDCG, 'g'+'--', label='FedAvg user 5 balance data',linewidth=2)
#plt.plot(epochs, FedAvg_unbalance_user5_NDCG, 'y'+'--', label='FedAvg user 5 unbalance data',linewidth=2)
plt.plot(epochs, FedAvg_balance_user10_NDCG, 'g'+'-', label='FedAvg user 10 balance data',linewidth=2)
plt.plot(epochs, FedAvg_unbalance_user10_NDCG, 'g'+'--', label='FedAvg user 10 unbalance data',linewidth=2)


font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('NDCG', font1)
plt.title('balance & unbalance', font1)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 14)
plt.savefig(r"./result/compare/user_10_balance_and_unbalance_NDCG")

# %%
pFedMe_balance_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_unbalance_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_balance_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
pFedMe_unbalance_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_balance_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_unbalance_user10_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_balance_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_unbalance_user5_HR = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")

#plt.axis([0, 40, 0, 0.7])
epochs = [x for x in range(0, 80, 1)]

plt.plot(epochs, pFedMe_balance_user5_HR, 'b'+'-', label='pFed user 5 balance data',linewidth=2)
plt.plot(epochs, pFedMe_unbalance_user5_HR, 'b'+'--', label='pFed user 5 unbalance data',linewidth=2)
#plt.plot(epochs, pFedMe_balance_user10_HR, 'b'+'-', label='pFed user 10 balance data',linewidth=2)
#plt.plot(epochs, pFedMe_unbalance_user10_HR, 'b'+'--', label='pFed user 10 unbalance data',linewidth=2)
plt.plot(epochs, FedAvg_balance_user5_HR, 'g'+'-', label='FedAvg user 5 balance data',linewidth=2)
plt.plot(epochs, FedAvg_unbalance_user5_HR, 'g'+'--', label='FedAvg user 5 unbalance data',linewidth=2)
#plt.plot(epochs, FedAvg_balance_user10_HR, 'g'+'-', label='FedAvg user 10 balance data',linewidth=2)
#plt.plot(epochs, FedAvg_unbalance_user10_HR, 'g'+'--', label='FedAvg user 10 unbalance data',linewidth=2)


font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
plt.title('balance & unbalance', font1)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 14)
plt.savefig(r"./result/compare/user_5_balance_and_unbalance_HR")

# %%
pFedMe_balance_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_unbalance_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_balance_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
pFedMe_unbalance_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_balance_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_unbalance_user10_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_10_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_balance_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_unbalance_user5_NDCG = process_privacy_data(r"./2021-09-12-21-07-04/_balance_False_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")

#plt.axis([0, 40, 0, 0.5])
epochs = [x for x in range(0, 39, 1)]

plt.plot(epochs, pFedMe_balance_user5_NDCG, 'b'+'-', label='pFed user 5 balance data',linewidth=2)
plt.plot(epochs, pFedMe_unbalance_user5_NDCG, 'b'+'--', label='pFed user 5 unbalance data',linewidth=2)
#plt.plot(epochs, pFedMe_balance_user10_NDCG, 'b'+'-', label='pFed user 10 balance data',linewidth=2)
#plt.plot(epochs, pFedMe_unbalance_user10_NDCG, 'b'+'--', label='pFed user 10 unbalance data',linewidth=2)
plt.plot(epochs, FedAvg_balance_user5_NDCG, 'g'+'-', label='FedAvg user 5 balance data',linewidth=2)
plt.plot(epochs, FedAvg_unbalance_user5_NDCG, 'g'+'--', label='FedAvg user 5 unbalance data',linewidth=2)
#plt.plot(epochs, FedAvg_balance_user10_NDCG, 'g'+'-', label='FedAvg user 10 balance data',linewidth=2)
#plt.plot(epochs, FedAvg_unbalance_user10_NDCG, 'g'+'--', label='FedAvg user 10 unbalance data',linewidth=2)


font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('NDCG', font1)
plt.title('balance & unbalance', font1)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 14)
plt.savefig(r"./result/compare/user_5_balance_and_unbalance_NDCG")

# %%
#pFedMe_Lr_01_user5_HR = process_privacy_data(r"./different_lr/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
#pFedMe_Lr_005_user5_HR = process_privacy_data(r"./different_lr/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.005_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_Lr_01_user5_HR = process_privacy_data(r"./different_lr/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_HR/total_test_HR.txt")
FedAvg_Lr_005_user5_HR = process_privacy_data(r"./different_lr/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.005_/logs/server/total_test_HR/total_test_HR.txt")

epochs = [x for x in range(0, 68, 1)]
#plt.axis([0, 70, 0, 0.7])

#plt.plot(epochs, pFedMe_Lr_01_user5_HR, 'b'+'--', label='pFed user 5 lr 0.01 data',linewidth=2)
#plt.plot(epochs, pFedMe_Lr_005_user5_HR, 'm'+'--', label='pFed user 5 lr 0.005 data',linewidth=2)

plt.plot(epochs, FedAvg_Lr_01_user5_HR, 'b'+'-', label='FedAvg user 5 lr 0.01 data',linewidth=2)
plt.plot(epochs, FedAvg_Lr_005_user5_HR, 'm'+'-', label='FedAvg user 5 lr 0.005 data',linewidth=2)



font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('HR', font1)
#plt.title('', font1)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 14)
plt.savefig(r"./result/compare/user_5_differen_lr_HR")

# %%
#pFedMe_Lr_01_user5_NDCG = process_privacy_data(r"./different_lr/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
#pFedMe_Lr_005_user5_NDCG = process_privacy_data(r"./different_lr/_balance_True_user_5_DP_False_algorithm_pFedMe_GlobalLr_0.75_PersonalLr_0.005_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_Lr_01_user5_NDCG = process_privacy_data(r"./different_lr/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.01_/logs/server/total_test_NDCG/total_test_NDCG.txt")
FedAvg_Lr_005_user5_NDCG = process_privacy_data(r"./different_lr/_balance_True_user_5_DP_False_algorithm_FedAvg_GlobalLr_0.75_PersonalLr_0.005_/logs/server/total_test_NDCG/total_test_NDCG.txt")

epochs = [x for x in range(0, 68, 1)]
#plt.axis([0, 70, 0, 0.5])

#plt.plot(epochs, pFedMe_Lr_01_user5_NDCG, 'b'+'--', label='pFed user 5 lr 0.01 data',linewidth=2)
#plt.plot(epochs, pFedMe_Lr_005_user5_NDCG, 'm'+'--', label='pFed user 5 lr 0.005 data',linewidth=2)

plt.plot(epochs, FedAvg_Lr_01_user5_NDCG, 'b'+'-', label='FedAvg user 5 lr 0.01 data',linewidth=2)
plt.plot(epochs, FedAvg_Lr_005_user5_NDCG, 'm'+'-', label='FedAvg user 5 lr 0.005 data',linewidth=2)



font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 30,
}

plt.tick_params(labelsize=30)
plt.legend(prop=font1)
plt.xlabel('epochs', font1)
plt.ylabel('NDCG', font1)
#plt.title('', font1)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 14)
plt.savefig(r"./result/compare/user_5_differen_lr_NDCG")
